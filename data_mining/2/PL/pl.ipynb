# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('nba.csv')
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      457 non-null    object
#  1   Team      457 non-null    object
#  2   Number    457 non-null    float64
#  3   Position  457 non-null    object
#  4   Age       457 non-null    float64
#  5   Height    457 non-null    object
#  6   Weight    457 non-null    float64
#  7   College   373 non-null    object
#  8   Salary    446 non-null    float64
# dtypes: float64(4), object(5)
# memory usage: 32.3+ KB

# %%
df.size
# Out:
# 4122

# %%
df.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
# View the first rows of the data set
df[:10]
# Out:
#             Name            Team  Number Position   Age Height  Weight  \
# 0  Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1    Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2   John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3    R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4  Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# 5   Amir Johnson  Boston Celtics    90.0       PF  29.0    6-9   240.0
# 6  Jordan Mickey  Boston Celtics    55.0       PF  21.0    6-8   235.0
# 7   Kelly Olynyk  Boston Celtics    41.0        C  25.0    7-0   238.0
# 8   Terry Rozier  Boston Celtics    12.0       PG  22.0    6-2   190.0
# 9   Marcus Smart  Boston Celtics    36.0       PG  22.0    6-4   220.0
#
#              College      Salary
# 0              Texas   7730337.0
# 1          Marquette   6796117.0
# 2  Boston University         NaN
# 3      Georgia State   1148640.0
# ...

# %%
# Select the last rows
df[-10:]
# Out:
#                Name       Team  Number Position   Age Height  Weight  \
# 448  Gordon Hayward  Utah Jazz    20.0       SF  26.0    6-8   226.0
# 449     Rodney Hood  Utah Jazz     5.0       SG  23.0    6-8   206.0
# 450      Joe Ingles  Utah Jazz     2.0       SF  28.0    6-8   226.0
# 451   Chris Johnson  Utah Jazz    23.0       SF  26.0    6-6   206.0
# 452      Trey Lyles  Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453    Shelvin Mack  Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454       Raul Neto  Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455    Tibor Pleiss  Utah Jazz    21.0        C  26.0    7-3   256.0
# 456     Jeff Withey  Utah Jazz    24.0        C  26.0    7-0   231.0
# 457             NaN        NaN     NaN      NaN   NaN    NaN     NaN
#
#       College      Salary
# 448    Butler  15409570.0
# 449      Duke   1348440.0
# 450       NaN   2050000.0
# 451    Dayton    981348.0
# 452  Kentucky   2239800.0
# 453    Butler   2433333.0
# ...

# %%
college = df[['College']]
type(college)
# Out:
# pandas.core.frame.DataFrame

# %%
# Select columns Name, Position, College, and rows 15 to 20
df[['Name', 'Position', 'College']][15:21]
# df.loc[15:21, ['Name', 'Position', 'College']] # Another way to do this
# df.iloc[15:21, [0, 3, 7]] # yet another way
# Out:
#                        Name Position         College
# 15         Bojan Bogdanovic       SG             NaN
# 16             Markel Brown       SG  Oklahoma State
# 17          Wayne Ellington       SG  North Carolina
# 18  Rondae Hollis-Jefferson       SG         Arizona
# 19             Jarrett Jack       PG    Georgia Tech
# 20           Sergey Karasev       SG             NaN

# %%
# View all players from Position = 'PF'
df.loc[df['Position'] == 'SG']
# Out:
#                  Name                    Team  Number Position   Age Height  \
# 2        John Holland          Boston Celtics    30.0       SG  27.0    6-5
# 3         R.J. Hunter          Boston Celtics    28.0       SG  22.0    6-5
# 12        Evan Turner          Boston Celtics    11.0       SG  27.0    6-7
# 13        James Young          Boston Celtics    13.0       SG  20.0    6-6
# 15   Bojan Bogdanovic           Brooklyn Nets    44.0       SG  27.0    6-8
# ..                ...                     ...     ...      ...   ...    ...
# 433  Gerald Henderson  Portland Trail Blazers     9.0       SG  28.0    6-5
# 437     C.J. McCollum  Portland Trail Blazers     3.0       SG  24.0    6-4
# 438      Luis Montero  Portland Trail Blazers    44.0       SG  23.0    6-7
# 444        Alec Burks               Utah Jazz    10.0       SG  24.0    6-6
# 449       Rodney Hood               Utah Jazz     5.0       SG  23.0    6-8
#
#      Weight            College     Salary
# ...

# %%
# View all distinct values from the Team column, and their numbers.
df['Team'].value_counts()
# Out:
# ['Boston Celtics' 'Brooklyn Nets' 'New York Knicks' 'Philadelphia 76ers'
#  'Toronto Raptors' 'Golden State Warriors' 'Los Angeles Clippers'
#  'Los Angeles Lakers' 'Phoenix Suns' 'Sacramento Kings' 'Chicago Bulls'
#  'Cleveland Cavaliers' 'Detroit Pistons' 'Indiana Pacers'
#  'Milwaukee Bucks' 'Dallas Mavericks' 'Houston Rockets'
#  'Memphis Grizzlies' 'New Orleans Pelicans' 'San Antonio Spurs'
#  'Atlanta Hawks' 'Charlotte Hornets' 'Miami Heat' 'Orlando Magic'
#  'Washington Wizards' 'Denver Nuggets' 'Minnesota Timberwolves'
#  'Oklahoma City Thunder' 'Portland Trail Blazers' 'Utah Jazz' nan]
# Team
# New Orleans Pelicans      19
# Memphis Grizzlies         18
# New York Knicks           16
# Milwaukee Bucks           16
# Boston Celtics            15
# Brooklyn Nets             15
# Portland Trail Blazers    15
# Oklahoma City Thunder     15
# Denver Nuggets            15
# Washington Wizards        15
# Miami Heat                15
# Charlotte Hornets         15
# ...

# %%
# View players from Team = Los Angeles Lakers (all columns except Team)
df.loc[df['Team'] == 'Los Angeles Lakers'].drop('Team', axis=1)
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# View the data in reverse alphabetical order of College and decreasing Age
df.sort_values(by=['College', 'Age'], ascending=[True, False])
# Out:
#                    Name                  Team  Number Position   Age Height  \
# 180         Mo Williams   Cleveland Cavaliers    52.0       PG  33.0    6-1
# 287          Alonzo Gee  New Orleans Pelicans    15.0       SF  29.0    6-6
# 266      JaMychal Green     Memphis Grizzlies     0.0       PF  25.0    6-9
# 256         Jason Terry       Houston Rockets    31.0       SG  38.0    6-2
# 170   Richard Jefferson   Cleveland Cavaliers    24.0       SF  35.0    6-7
# ..                  ...                   ...     ...      ...   ...    ...
# 40   Kristaps Porzingis       New York Knicks     6.0       PF  20.0    7-3
# 62        Bruno Caboclo       Toronto Raptors    20.0       SF  20.0    6-9
# 393     Emmanuel Mudiay        Denver Nuggets     0.0       PG  20.0    6-5
# 445          Dante Exum             Utah Jazz    11.0       PG  20.0    6-6
# 457                 NaN                   NaN     NaN      NaN   NaN    NaN
#
#      Weight  College     Salary
# ...

# %%
# View the data in descending order of salary
df.sort_values(by='Salary', ascending=False)
# Out:
#                 Name                    Team  Number Position   Age Height  \
# 109      Kobe Bryant      Los Angeles Lakers    24.0       SF  37.0    6-6
# 169     LeBron James     Cleveland Cavaliers    23.0       SF  31.0    6-8
# 33   Carmelo Anthony         New York Knicks     7.0       SF  32.0    6-8
# 251    Dwight Howard         Houston Rockets    12.0        C  30.0   6-11
# 339       Chris Bosh              Miami Heat     1.0       PF  32.0   6-11
# ..               ...                     ...     ...      ...   ...    ...
# 350    Briante Weber              Miami Heat    12.0       PG  23.0    6-2
# 353    Dorell Wright              Miami Heat    11.0       SF  30.0    6-9
# 397     Axel Toupane          Denver Nuggets     6.0       SG  23.0    6-7
# 409       Greg Smith  Minnesota Timberwolves     4.0       PF  25.0   6-10
# 457              NaN                     NaN     NaN      NaN   NaN    NaN
#
#      Weight                College      Salary
# ...

# %%
# Make a salary histogram
df[['Salary']].hist();

# %%
# Make an age boxplot
df[['Age']].boxplot()
# Out:
# <Axes: >

# %%
# Make a salary vs. age plot
df.plot.scatter(x='Age', y='Salary', title='Salary = f(Age)')
# Out:
# <Axes: title={'center': 'Salary = f(Age)'}, xlabel='Age', ylabel='Salary'>

# %%
# View the age and average salary of the players
df[['Age','Salary']].mean()
# Out:
# Age       2.693873e+01
# Salary    4.842684e+06
# dtype: float64

# %%
# Present players for whom the age is lower than average and the salary is higher than average.
df[(df['Age'] < df['Age'].mean()) & (df['Salary'] > df['Salary'].mean())].sort_values(by='Age')
# Out:
#                        Name                    Team  Number Position   Age  \
# 410      Karl-Anthony Towns  Minnesota Timberwolves    32.0        C  20.0
# 116        D'Angelo Russell      Los Angeles Lakers     1.0       PG  20.0
# 223           Jabari Parker         Milwaukee Bucks    12.0       PF  21.0
# 411          Andrew Wiggins  Minnesota Timberwolves    22.0       SG  21.0
# 369            Bradley Beal      Washington Wizards     3.0       SG  22.0
# 332  Michael Kidd-Gilchrist       Charlotte Hornets    14.0       SF  22.0
# 189           Tobias Harris         Detroit Pistons    34.0       SF  23.0
# 281           Anthony Davis    New Orleans Pelicans    23.0       PF  23.0
# 363          Victor Oladipo           Orlando Magic     5.0       SG  24.0
# 219         Khris Middleton         Milwaukee Bucks    22.0       SG  24.0
# 168            Kyrie Irving     Cleveland Cavaliers     2.0       PG  24.0
# ...

# %%
# Get the salary variable statistics grouped by team
df.groupby('Team').describe()
# Out:
#                        Number                                                 \
#                         count       mean        std  min    25%   50%    75%
# Team
# Atlanta Hawks            15.0  19.000000  11.476684  0.0  11.50  17.0  25.50
# Boston Celtics           15.0  31.866667  30.300558  0.0   9.50  28.0  42.50
# Brooklyn Nets            15.0  18.266667  14.104035  0.0   8.00  15.0  27.00
# Charlotte Hornets        15.0  17.133333  16.672761  0.0   4.00  12.0  27.50
# Chicago Bulls            15.0  19.200000  17.193022  0.0   5.50  16.0  28.00
# Cleveland Cavaliers      15.0  14.466667  13.809245  0.0   4.50  12.0  21.50
# Dallas Mavericks         15.0  20.000000  16.252472  1.0   6.00  21.0  30.50
# Denver Nuggets           15.0  15.266667  19.655849  0.0   4.00   9.0  18.00
# Detroit Pistons          15.0  17.266667  15.303906  0.0   5.50  13.0  23.50
# Golden State Warriors    15.0  20.866667  11.413442  4.0  11.50  20.0  30.50
# ...

# %%
# Make a boxplot of salary vs. Team
df.plot.box(by='Team', column='Salary');

# %%
# Get the average salary per position
df.groupby('Position')['Salary'].mean()
# Out:
# Position
# C     5.967052e+06
# PF    4.562483e+06
# PG    5.077829e+06
# SF    4.857393e+06
# SG    4.009861e+06
# Name: Salary, dtype: float64

# %%
# Make a boxplot of salary vs. Position
df.plot.box(by='Position', column='Salary');

# %%
# Get the statistics of the Age variable grouped by Position
df.groupby('Position')['Age'].describe()
# Out:
#           count       mean       std   min   25%   50%    75%   max
# Position
# C          78.0  27.371795  4.156388  20.0  24.0  27.0  30.00  40.0
# PF        100.0  27.160000  4.607241  20.0  24.0  27.0  30.00  40.0
# PG         92.0  26.847826  4.169314  20.0  24.0  26.5  30.00  40.0
# SF         85.0  26.858824  4.386540  20.0  23.0  26.0  29.00  38.0
# SG        102.0  26.539216  4.643043  19.0  23.0  25.0  29.75  39.0

# %%
# Count number of Nas per column
df.isnull().sum()
# Out:
# Name         1
# Team         1
# Number       1
# Position     1
# Age          1
# Height       1
# Weight       1
# College     85
# Salary      12
# dtype: int64

# %%
# Remove line with Name, Team, Number, Position, Age, Height, Weight: NaN
df.dropna(subset=['Name', 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight'])
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 452     Trey Lyles       Utah Jazz    41.0       PF  20.0   6-10   234.0
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# Presents for each dateFrame column the number of NAs and their percentage
nulls = df.isnull().sum()
percentages = round(df.isnull().mean()*100, 1)
pd.concat([nulls, percentages], axis=1)
# Out:
#            0     1
# Name       1   0.2
# Team       1   0.2
# Number     1   0.2
# Position   1   0.2
# Age        1   0.2
# Height     1   0.2
# Weight     1   0.2
# College   85  18.6
# Salary    12   2.6

# %%
# Fill in College column NaN values with 'no College'
# df.College = df.College.fillna('no College')
df.College.fillna('no College', inplace=True) #- this mutates the original DF
df
# Out:
#               Name            Team  Number Position   Age Height  Weight  \
# 0    Avery Bradley  Boston Celtics     0.0       PG  25.0    6-2   180.0
# 1      Jae Crowder  Boston Celtics    99.0       SF  25.0    6-6   235.0
# 2     John Holland  Boston Celtics    30.0       SG  27.0    6-5   205.0
# 3      R.J. Hunter  Boston Celtics    28.0       SG  22.0    6-5   185.0
# 4    Jonas Jerebko  Boston Celtics     8.0       PF  29.0   6-10   231.0
# ..             ...             ...     ...      ...   ...    ...     ...
# 453   Shelvin Mack       Utah Jazz     8.0       PG  26.0    6-3   203.0
# 454      Raul Neto       Utah Jazz    25.0       PG  24.0    6-1   179.0
# 455   Tibor Pleiss       Utah Jazz    21.0        C  26.0    7-3   256.0
# 456    Jeff Withey       Utah Jazz    24.0        C  26.0    7-0   231.0
# 457            NaN             NaN     NaN      NaN   NaN    NaN     NaN
#
#                College        Salary
# 0                Texas  7.730337e+06
# ...

# %%
df.drop(457, inplace=True)

# %%
# View the lines with Salary NaN
df[df['Salary'].isna()]
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %%
# Fill in the salary NaN values with the average salary value of the respective Team/Position
for row in df[df['Salary'].isna()].itertuples():
    df.at[row.Index, 'Salary'] = df[(df['Team'] == row.Team) & (df['Position'] == row.Position)]['Salary'].mean()

# %%
# Count the number of Nas throughout all the dataframe
df.isna().sum().sum()
# Out:
# 0

# %%
# Save the dataframe in a csv file and an excel file.
df.to_csv('result.csv')

# %%
df.to_excel('result.xlsx')
